# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = "/content/drive/MyDrive/Cursos/Valerio_Velardo/Deep_Learning_for_audio/data.json"

# %%
def load_data(dataset_path):
  with open(dataset_path, 'r') as fp:
    data = json.load(fp)

  # convertir list a numpy array
  inputs = np.array(data['mfcc'])
  targets = np.array(data['labels'])
  return inputs, targets

def split_data(inputs, targets, test_size):
  return train_test_split(inputs, targets, test_size=test_size)

def plot_history(history):
  fig, axs = plt.subplots(2)

  # create accuracy subplot
  axs[0].plot(history.history['accuracy'], label='train accuracy')
  axs[0].plot(history.history['val_accuracy'], label='test accuracy')
  axs[0].set_ylabel('Accuracy')
  axs[0].legend(loc='lower right')
  axs[0].set_title('Accuracy eval')

  # create error subplot
  axs[1].plot(history.history['loss'], label='train error')
  axs[1].plot(history.history['val_loss'], label='test error')
  axs[1].set_ylabel('Error')
  axs[1].set_xlabel('Epoch')
  axs[1].legend(loc='upper right')
  axs[1].set_title('Error eval')

  plt.show()

# %%
if __name__ == "__main__":
  # load data
  inputs, targets = load_data(DATA_PATH)
  # split data into train and test set
  inputs_train, inputs_test, targets_train, targets_test = split_data(inputs, targets, 0.3)
  # build the networkt arquitecture
  model = keras.Sequential([
      # input layer
      keras.layers.Flatten(input_shape=(inputs.shape[1], inputs.shape[2])), #(time interval, value coefficient in interval)
      # 1st hidden layer
      keras.layers.Dense(512, activation='relu'),
      # 2st hidden layer
      keras.layers.Dense(256, activation='relu'),
      # 3st hidden layer
      keras.layers.Dense(64, activation='relu'),
      # output layer
      keras.layers.Dense(10, activation='softmax') # 10 categories
  ])
  # compile network
  optimizer = keras.optimizers.Adam(learning_rate=0.0001)
  model.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  model.summary()

  # train network
  history = model.fit(inputs_train, targets_train, validation_data=(inputs_test, targets_test), epochs=50, batch_size=32)

  # plot accuracy and error over the epochs
  plot_history(history)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 1690)              0
#
#  dense (Dense)               (None, 512)               865792
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1014218 (3.87 MB)
# Trainable params: 1014218 (3.87 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 219/219 [==============================] - 11s 43ms/step - loss: 7.7443 - accuracy: 0.3126 - val_loss: 3.9839 - val_accuracy: 0.3418
# Epoch 2/50
# 219/219 [==============================] - 8s 38ms/step - loss: 2.9681 - accuracy: 0.4199 - val_loss: 2.9179 - val_accuracy: 0.3969
# Epoch 3/50
# 219/219 [==============================] - 5s 24ms/step - loss: 2.1012 - accuracy: 0.4894 - val_loss: 2.8802 - val_accuracy: 0.4156
# Epoch 4/50
# 219/219 [==============================] - 8s 34ms/step - loss: 1.6198 - accuracy: 0.5514 - val_loss: 2.4501 - val_accuracy: 0.4306
# Epoch 5/50
# 219/219 [==============================] - 5s 21ms/step - loss: 1.3475 - accuracy: 0.6049 - val_loss: 2.2261 - val_accuracy: 0.4750
# Epoch 6/50
# 219/219 [==============================] - 6s 28ms/step - loss: 1.1440 - accuracy: 0.6591 - val_loss: 2.3593 - val_accuracy: 0.4763
# Epoch 7/50
# 219/219 [==============================] - 7s 31ms/step - loss: 1.0235 - accuracy: 0.6798 - val_loss: 2.0763 - val_accuracy: 0.4963
# Epoch 8/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.8664 - accuracy: 0.7209 - val_loss: 2.1797 - val_accuracy: 0.4967
# Epoch 9/50
# 219/219 [==============================] - 8s 35ms/step - loss: 0.7433 - accuracy: 0.7528 - val_loss: 2.2157 - val_accuracy: 0.4997
# Epoch 10/50
# 219/219 [==============================] - 7s 34ms/step - loss: 0.6656 - accuracy: 0.7794 - val_loss: 2.0448 - val_accuracy: 0.5270
# Epoch 11/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.5956 - accuracy: 0.8043 - val_loss: 2.1179 - val_accuracy: 0.5177
# Epoch 12/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.5856 - accuracy: 0.8103 - val_loss: 2.1246 - val_accuracy: 0.5167
# Epoch 13/50
# 219/219 [==============================] - 7s 31ms/step - loss: 0.4719 - accuracy: 0.8411 - val_loss: 2.0031 - val_accuracy: 0.5377
# Epoch 14/50
# 219/219 [==============================] - 8s 39ms/step - loss: 0.4298 - accuracy: 0.8565 - val_loss: 2.2047 - val_accuracy: 0.5347
# Epoch 15/50
# 219/219 [==============================] - 6s 29ms/step - loss: 0.3835 - accuracy: 0.8722 - val_loss: 2.1177 - val_accuracy: 0.5407
# Epoch 16/50
# 219/219 [==============================] - 8s 35ms/step - loss: 0.3674 - accuracy: 0.8804 - val_loss: 2.5885 - val_accuracy: 0.5070
# Epoch 17/50
# 219/219 [==============================] - 7s 32ms/step - loss: 0.3563 - accuracy: 0.8837 - val_loss: 2.0488 - val_accuracy: 0.5577
# Epoch 18/50
# 219/219 [==============================] - 7s 34ms/step - loss: 0.2537 - accuracy: 0.9192 - val_loss: 2.0726 - val_accuracy: 0.5678
# Epoch 19/50
# 219/219 [==============================] - 6s 29ms/step - loss: 0.2013 - accuracy: 0.9355 - val_loss: 2.2996 - val_accuracy: 0.5437
# Epoch 20/50
# 219/219 [==============================] - 10s 44ms/step - loss: 0.2351 - accuracy: 0.9229 - val_loss: 2.2403 - val_accuracy: 0.5441
# Epoch 21/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.3517 - accuracy: 0.8888 - val_loss: 2.2532 - val_accuracy: 0.5681
# Epoch 22/50
# 219/219 [==============================] - 6s 25ms/step - loss: 0.2196 - accuracy: 0.9275 - val_loss: 2.2491 - val_accuracy: 0.5661
# Epoch 23/50
# 219/219 [==============================] - 9s 40ms/step - loss: 0.1637 - accuracy: 0.9494 - val_loss: 2.3257 - val_accuracy: 0.5638
# Epoch 24/50
# 219/219 [==============================] - 7s 32ms/step - loss: 0.1322 - accuracy: 0.9614 - val_loss: 2.3318 - val_accuracy: 0.5521
# Epoch 25/50
# 219/219 [==============================] - 6s 30ms/step - loss: 0.1917 - accuracy: 0.9411 - val_loss: 2.2589 - val_accuracy: 0.5694
# Epoch 26/50
# 219/219 [==============================] - 8s 34ms/step - loss: 0.1310 - accuracy: 0.9587 - val_loss: 2.3162 - val_accuracy: 0.5664
# Epoch 27/50
# 219/219 [==============================] - 7s 33ms/step - loss: 0.1317 - accuracy: 0.9598 - val_loss: 2.3894 - val_accuracy: 0.5731
# Epoch 28/50
# 219/219 [==============================] - 8s 35ms/step - loss: 0.2055 - accuracy: 0.9336 - val_loss: 2.4889 - val_accuracy: 0.5664
# Epoch 29/50
# 219/219 [==============================] - 7s 31ms/step - loss: 0.1476 - accuracy: 0.9546 - val_loss: 2.5697 - val_accuracy: 0.5778
# Epoch 30/50
# 219/219 [==============================] - 5s 24ms/step - loss: 0.1850 - accuracy: 0.9389 - val_loss: 2.3381 - val_accuracy: 0.5891
# Epoch 31/50
# 219/219 [==============================] - 6s 28ms/step - loss: 0.0993 - accuracy: 0.9722 - val_loss: 2.5460 - val_accuracy: 0.5624
# Epoch 32/50
# 219/219 [==============================] - 6s 28ms/step - loss: 0.2719 - accuracy: 0.9182 - val_loss: 2.5177 - val_accuracy: 0.5634
# Epoch 33/50
# 219/219 [==============================] - 7s 30ms/step - loss: 0.1422 - accuracy: 0.9541 - val_loss: 2.2659 - val_accuracy: 0.6045
# Epoch 34/50
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0532 - accuracy: 0.9877 - val_loss: 2.2779 - val_accuracy: 0.6075
# Epoch 35/50
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0422 - accuracy: 0.9893 - val_loss: 2.2946 - val_accuracy: 0.6061
# Epoch 36/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0779 - accuracy: 0.9774 - val_loss: 2.4464 - val_accuracy: 0.5748
# Epoch 37/50
# 219/219 [==============================] - 8s 38ms/step - loss: 0.2080 - accuracy: 0.9333 - val_loss: 2.4033 - val_accuracy: 0.5955
# Epoch 38/50
# 219/219 [==============================] - 8s 35ms/step - loss: 0.1832 - accuracy: 0.9405 - val_loss: 2.4087 - val_accuracy: 0.5874
# Epoch 39/50
# 219/219 [==============================] - 6s 28ms/step - loss: 0.0958 - accuracy: 0.9701 - val_loss: 2.5647 - val_accuracy: 0.5928
# Epoch 40/50
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0815 - accuracy: 0.9754 - val_loss: 2.4942 - val_accuracy: 0.6055
# Epoch 41/50
# 219/219 [==============================] - 7s 32ms/step - loss: 0.1046 - accuracy: 0.9680 - val_loss: 2.5025 - val_accuracy: 0.6008
# Epoch 42/50
# 219/219 [==============================] - 10s 45ms/step - loss: 0.1128 - accuracy: 0.9632 - val_loss: 2.4657 - val_accuracy: 0.6075
# Epoch 43/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.1210 - accuracy: 0.9609 - val_loss: 2.6147 - val_accuracy: 0.5881
# Epoch 44/50
# 219/219 [==============================] - 8s 38ms/step - loss: 0.0864 - accuracy: 0.9720 - val_loss: 2.4859 - val_accuracy: 0.6098
# Epoch 45/50
# 219/219 [==============================] - 8s 34ms/step - loss: 0.0468 - accuracy: 0.9860 - val_loss: 2.9401 - val_accuracy: 0.5771
# Epoch 46/50
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0821 - accuracy: 0.9747 - val_loss: 2.6305 - val_accuracy: 0.5878
# Epoch 47/50
# 219/219 [==============================] - 10s 45ms/step - loss: 0.2625 - accuracy: 0.9230 - val_loss: 2.8967 - val_accuracy: 0.5871
# Epoch 48/50
# 219/219 [==============================] - 6s 28ms/step - loss: 0.1495 - accuracy: 0.9528 - val_loss: 2.6266 - val_accuracy: 0.6138
# Epoch 49/50
# 219/219 [==============================] - 10s 45ms/step - loss: 0.0617 - accuracy: 0.9815 - val_loss: 2.4844 - val_accuracy: 0.6255
# Epoch 50/50
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0335 - accuracy: 0.9917 - val_loss: 2.4552 - val_accuracy: 0.6168

# %%
# HAY OVERFITTING
