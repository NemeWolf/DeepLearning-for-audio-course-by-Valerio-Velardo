# %%
import numpy as np
from random import random
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
def generate_dataset(num_samples, test_size):
  x = np.array([[random()/2 for _ in range(2)] for _ in range(num_samples)])
  y = np.array([[i[0] + i[1]] for i in x])
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size)
  return x_train, x_test, y_train, y_test

# %%
if __name__ == "__main__":
  x_train, x_test, y_train, y_test = generate_dataset(5000, 0.3)
  # print("x_test: \n{}".format(x_test))
  # print("y_test: \n{}".format(y_test))

  # Build model: 2 -> 5 -> 1
  model=tf.keras.Sequential([
  tf.keras.layers.Dense(5, input_dim=2, activation="sigmoid"),
  tf.keras.layers.Dense(1, activation="sigmoid")
  ])

  #Keras: libreria de alto nivel situada en la cima de tensorflow
  #Sequential: hace que la red sea de izq a der
  #dense layer: fullu connected layer (NN)

  # Compile model
  optimiser = tf.keras.optimizers.SGD(learning_rate=0.1)
  model.compile(loss="MSE", optimizer=optimiser, metrics=["binary_accuracy"])

  # Train model
  model.fit(x_train, y_train, epochs=100)

  # Evaluate model
  print("\nModel evaluation:")
  model.evaluate(x_test, y_test, verbose=1)

  # Make predictions
  #array([[0.1, 0.2],[0.2,0.2]])
  #array([[0.3],[0.4]])
  data = np.array([[0.1, 0.2], [0.2, 0.2]])
  predictions = model.predict(data)

  print("\nSome predictions:")
  for d, p in zip(data, predictions):
    print("{} + {} = {}".format(d[0], d[1], p[0]))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - binary_accuracy: 0.0000e+00 - loss: 0.0663
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.0000e+00 - loss: 0.0401
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.0000e+00 - loss: 0.0400
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.0000e+00 - loss: 0.0382
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.0000e+00 - loss: 0.0395
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.0000e+00 - loss: 0.0397
# Epoch 7/100
# ...
