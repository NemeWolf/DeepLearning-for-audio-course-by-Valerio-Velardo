# %%
import numpy as np
from random import random
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
def generate_dataset(num_samples, test_size):
  x = np.array([[random()/2 for _ in range(2)] for _ in range(num_samples)])
  y = np.array([[i[0] + i[1]] for i in x])
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size)
  return x_train, x_test, y_train, y_test

# %%
if __name__ == "__main__":
  x_train, x_test, y_train, y_test = generate_dataset(5000, 0.3)
  # print("x_test: \n{}".format(x_test))
  # print("y_test: \n{}".format(y_test))

  # Build model: 2 -> 5 -> 1
  model=tf.keras.Sequential([
  tf.keras.layers.Dense(5, input_dim=2, activation="sigmoid"),
  tf.keras.layers.Dense(1, activation="sigmoid")
  ])

  #Keras: libreria de alto nivel situada en la cima de tensorflow
  #Sequential: hace que la red sea de izq a der
  #dense layer: fullu connected layer (NN)

  # Compile model
  optimiser = tf.keras.optimizers.SGD(learning_rate=0.1)
  model.compile(loss="MSE", optimizer=optimiser, metrics=["binary_accuracy"])

  # Train model
  model.fit(x_train, y_train, epochs=100)

  # Evaluate model
  print("\nModel evaluation:")
  model.evaluate(x_test, y_test, verbose=1)

  # Make predictions
  #array([[0.1, 0.2],[0.2,0.2]])
  #array([[0.3],[0.4]])
  data = np.array([[0.1, 0.2], [0.2, 0.2]])
  predictions = model.predict(data)

  print("\nSome predictions:")
  for d, p in zip(data, predictions):
    print("{} + {} = {}".format(d[0], d[1], p[0]))
# Out:
# Epoch 1/100
# g:\My Drive\Cursos\Valerio_Velardo\Deep_Learning_for_audio\Code\env\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - binary_accuracy: 0.0000e+00 - loss: 0.0488
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - binary_accuracy: 0.0000e+00 - loss: 0.0411
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - binary_accuracy: 0.0000e+00 - loss: 0.0408
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - binary_accuracy: 0.0000e+00 - loss: 0.0399
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - binary_accuracy: 0.0000e+00 - loss: 0.0404
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - binary_accuracy: 0.0000e+00 - loss: 0.0401
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - binary_accuracy: 0.0000e+00 - loss: 0.0406
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - binary_accuracy: 0.0000e+00 - loss: 0.0400
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - binary_accuracy: 0.0000e+00 - loss: 0.0385
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - binary_accuracy: 0.0000e+00 - loss: 0.0384
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - binary_accuracy: 0.0000e+00 - loss: 0.0394
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - binary_accuracy: 0.0000e+00 - loss: 0.0375
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - binary_accuracy: 0.0000e+00 - loss: 0.0374
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - binary_accuracy: 0.0000e+00 - loss: 0.0372
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - binary_accuracy: 0.0000e+00 - loss: 0.0366
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - binary_accuracy: 0.0000e+00 - loss: 0.0362
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - binary_accuracy: 0.0000e+00 - loss: 0.0372
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - binary_accuracy: 0.0000e+00 - loss: 0.0358
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - binary_accuracy: 0.0000e+00 - loss: 0.0342
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - binary_accuracy: 0.0000e+00 - loss: 0.0349
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - binary_accuracy: 0.0000e+00 - loss: 0.0342
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - binary_accuracy: 0.0000e+00 - loss: 0.0327
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - binary_accuracy: 0.0000e+00 - loss: 0.0334
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - binary_accuracy: 0.0000e+00 - loss: 0.0329
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - binary_accuracy: 0.0000e+00 - loss: 0.0324
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - binary_accuracy: 0.0000e+00 - loss: 0.0318
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - binary_accuracy: 0.0000e+00 - loss: 0.0291
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - binary_accuracy: 0.0000e+00 - loss: 0.0292
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - binary_accuracy: 0.0000e+00 - loss: 0.0295
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - binary_accuracy: 0.0000e+00 - loss: 0.0285
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - binary_accuracy: 0.0000e+00 - loss: 0.0272
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - binary_accuracy: 0.0000e+00 - loss: 0.0275
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - binary_accuracy: 0.0000e+00 - loss: 0.0253
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - binary_accuracy: 0.0000e+00 - loss: 0.0253
# Epoch 35/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - binary_accuracy: 0.0000e+00 - loss: 0.0244
# Epoch 36/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - binary_accuracy: 0.0000e+00 - loss: 0.0234
# Epoch 37/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - binary_accuracy: 0.0000e+00 - loss: 0.0228
# Epoch 38/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - binary_accuracy: 0.0000e+00 - loss: 0.0221
# Epoch 39/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - binary_accuracy: 0.0000e+00 - loss: 0.0218
# Epoch 40/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - binary_accuracy: 0.0000e+00 - loss: 0.0207
# Epoch 41/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - binary_accuracy: 0.0000e+00 - loss: 0.0198
# Epoch 42/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - binary_accuracy: 0.0000e+00 - loss: 0.0186
# Epoch 43/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - binary_accuracy: 0.0000e+00 - loss: 0.0182
# Epoch 44/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - binary_accuracy: 0.0000e+00 - loss: 0.0178
# Epoch 45/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - binary_accuracy: 0.0000e+00 - loss: 0.0170
# Epoch 46/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - binary_accuracy: 0.0000e+00 - loss: 0.0159
# Epoch 47/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - binary_accuracy: 0.0000e+00 - loss: 0.0150
# Epoch 48/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - binary_accuracy: 0.0000e+00 - loss: 0.0143
# Epoch 49/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - binary_accuracy: 0.0000e+00 - loss: 0.0137
# Epoch 50/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - binary_accuracy: 0.0000e+00 - loss: 0.0131
# Epoch 51/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - binary_accuracy: 0.0000e+00 - loss: 0.0122
# Epoch 52/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - binary_accuracy: 0.0000e+00 - loss: 0.0117
# Epoch 53/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - binary_accuracy: 0.0000e+00 - loss: 0.0111
# Epoch 54/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - binary_accuracy: 0.0000e+00 - loss: 0.0104
# Epoch 55/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - binary_accuracy: 0.0000e+00 - loss: 0.0100
# Epoch 56/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - binary_accuracy: 0.0000e+00 - loss: 0.0092
# Epoch 57/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - binary_accuracy: 0.0000e+00 - loss: 0.0089
# Epoch 58/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - binary_accuracy: 0.0000e+00 - loss: 0.0083
# Epoch 59/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - binary_accuracy: 0.0000e+00 - loss: 0.0073
# Epoch 60/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - binary_accuracy: 0.0000e+00 - loss: 0.0073
# Epoch 61/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - binary_accuracy: 0.0000e+00 - loss: 0.0067
# Epoch 62/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - binary_accuracy: 0.0000e+00 - loss: 0.0065
# Epoch 63/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - binary_accuracy: 0.0000e+00 - loss: 0.0059
# Epoch 64/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - binary_accuracy: 0.0000e+00 - loss: 0.0055
# Epoch 65/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - binary_accuracy: 0.0000e+00 - loss: 0.0052
# Epoch 66/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - binary_accuracy: 0.0000e+00 - loss: 0.0051
# Epoch 67/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - binary_accuracy: 0.0000e+00 - loss: 0.0047
# Epoch 68/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - binary_accuracy: 0.0000e+00 - loss: 0.0044
# Epoch 69/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - binary_accuracy: 0.0000e+00 - loss: 0.0041
# Epoch 70/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - binary_accuracy: 0.0000e+00 - loss: 0.0038
# Epoch 71/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - binary_accuracy: 0.0000e+00 - loss: 0.0037
# Epoch 72/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - binary_accuracy: 0.0000e+00 - loss: 0.0033
# Epoch 73/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - binary_accuracy: 0.0000e+00 - loss: 0.0032
# Epoch 74/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - binary_accuracy: 0.0000e+00 - loss: 0.0030
# Epoch 75/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - binary_accuracy: 0.0000e+00 - loss: 0.0028
# Epoch 76/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - binary_accuracy: 0.0000e+00 - loss: 0.0027
# Epoch 77/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - binary_accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 78/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - binary_accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 79/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - binary_accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 80/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - binary_accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 81/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - binary_accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 82/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - binary_accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 83/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - binary_accuracy: 0.0000e+00 - loss: 0.0017
# Epoch 84/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - binary_accuracy: 0.0000e+00 - loss: 0.0016
# Epoch 85/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - binary_accuracy: 0.0000e+00 - loss: 0.0016
# Epoch 86/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - binary_accuracy: 0.0000e+00 - loss: 0.0014
# Epoch 87/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - binary_accuracy: 0.0000e+00 - loss: 0.0014
# Epoch 88/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - binary_accuracy: 0.0000e+00 - loss: 0.0013
# Epoch 89/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - binary_accuracy: 0.0000e+00 - loss: 0.0013
# Epoch 90/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - binary_accuracy: 0.0000e+00 - loss: 0.0013
# Epoch 91/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - binary_accuracy: 0.0000e+00 - loss: 0.0011
# Epoch 92/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - binary_accuracy: 0.0000e+00 - loss: 0.0010
# Epoch 93/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - binary_accuracy: 0.0000e+00 - loss: 0.0010
# Epoch 94/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - binary_accuracy: 0.0000e+00 - loss: 9.4535e-04
# Epoch 95/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - binary_accuracy: 0.0000e+00 - loss: 8.6707e-04
# Epoch 96/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - binary_accuracy: 0.0000e+00 - loss: 8.4788e-04
# Epoch 97/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - binary_accuracy: 0.0000e+00 - loss: 8.2749e-04
# Epoch 98/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - binary_accuracy: 0.0000e+00 - loss: 8.2918e-04
# Epoch 99/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - binary_accuracy: 0.0000e+00 - loss: 7.1965e-04
# Epoch 100/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - binary_accuracy: 0.0000e+00 - loss: 7.7057e-04
#
# Model evaluation:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - binary_accuracy: 0.0000e+00 - loss: 7.1645e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Some predictions:
# 0.1 + 0.2 = 0.3088570237159729
# 0.2 + 0.2 = 0.4009672701358795
