# %%
import numpy as np

# %%
class MLP:

  def __init__(self, num_inputs=3, num_hidden=[3, 5], num_outputs=2):
    self.num_inputs = num_inputs
    self.num_hidden = num_hidden
    self.num_outputs = num_outputs

    # Capa de entrada tendra dos neuronas
    # Habrán dos capas ocultas. La primera tendra 3 neuronas y la segunda 5 neuronas
    # Capa de salida tendra dos neuronas

    layers = [self.num_inputs] + self.num_hidden + [self.num_outputs]

    # inicializar pesos aleatorios

    self.weights = []

    # Crea matriz para cada par de capas
    for i in range(len(layers) - 1):
      w = np.random.rand(layers[i], layers[i + 1])  #Crea un arreglo de 2 dimeniones aleatorio (conexion de capa previa capa siguiente)
      self.weights.append(w)

  def forward_propagate(self, inputs):
    # inputs: vector

    activation = inputs

    for w in self.weights:
      # Calcula las entradas netas
      net_inputs = np.dot(activation, w)

      # Calcula la activacion
      activation = self._sigmoid(net_inputs)

    return activation

  def _sigmoid(self, x):
    return 1 / (1 + np.exp(-x))

# %%
if __name__ == "__main__":

  # crear un MLP
  mlp = MLP()

  # crear algun input
  inputs = np.random.rand(mlp.num_inputs)

  # correr la propagacion forward
  output = mlp.forward_propagate(inputs)

  # mostrar resultados
  print("The network input is: {}".format(inputs))
  print("The network output is: {}".format(output))
  print("The network weights is: {}".format(mlp.weights))
# Out:
# The network input is: [0.70292225 0.15912689 0.71895977]
# The network output is: [0.78686343 0.88753599]
# The network weights is: [array([[0.45452558, 0.59575241, 0.33329117],
#        [0.84975753, 0.85862567, 0.19867891],
#        [0.87015411, 0.84211636, 0.10733203]]), array([[0.58240706, 0.0336661 , 0.75186732, 0.15104015, 0.38901133],
#        [0.3347067 , 0.3769767 , 0.75158352, 0.4592633 , 0.83528074],
#        [0.4942613 , 0.53105652, 0.12757996, 0.59722639, 0.23948308]]), array([[0.31465846, 0.93868401],
#        [0.87210473, 0.58640601],
#        [0.30428678, 0.22403991],
#        [0.16132593, 0.5494236 ],
#        [0.22014048, 0.60336151]])]
