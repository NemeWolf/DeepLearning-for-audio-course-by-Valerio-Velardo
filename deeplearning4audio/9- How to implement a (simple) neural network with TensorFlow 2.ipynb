# %%
import numpy as np
from random import random
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
def generate_dataset(num_samples, test_size):
  x = np.array([[random()/2 for _ in range(2)] for _ in range(num_samples)])
  y = np.array([[i[0] + i[1]] for i in x])
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size)
  return x_train, x_test, y_train, y_test

# %%
if __name__ == "__main__":
  x_train, x_test, y_train, y_test = generate_dataset(5000, 0.3)
  # print("x_test: \n{}".format(x_test))
  # print("y_test: \n{}".format(y_test))

  # Build model: 2 -> 5 -> 1
  model=tf.keras.Sequential([
  tf.keras.layers.Dense(5, input_dim=2, activation="sigmoid"),
  tf.keras.layers.Dense(1, activation="sigmoid")
  ])

  #Keras: libreria de alto nivel situada en la cima de tensorflow
  #Sequential: hace que la red sea de izq a der
  #dense layer: fullu connected layer (NN)

  # Compile model
  optimiser = tf.keras.optimizers.SGD(learning_rate=0.1)
  model.compile(loss="MSE", optimizer=optimiser, metrics=["binary_accuracy"])

  # Train model
  model.fit(x_train, y_train, epochs=100)

  # Evaluate model
  print("\nModel evaluation:")
  model.evaluate(x_test, y_test, verbose=1)

  # Make predictions
  #array([[0.1, 0.2],[0.2,0.2]])
  #array([[0.3],[0.4]])
  data = np.array([[0.1, 0.2], [0.2, 0.2]])
  predictions = model.predict(data)

  print("\nSome predictions:")
  for d, p in zip(data, predictions):
    print("{} + {} = {}".format(d[0], d[1], p[0]))
# Out:
# Epoch 1/100
# c:\Users\nehem\AppData\Local\pypoetry\Cache\virtualenvs\deeplearning4audio-Djh0ILER-py3.12\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - binary_accuracy: 0.0000e+00 - loss: 0.0420
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - binary_accuracy: 0.0000e+00 - loss: 0.0409
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - binary_accuracy: 0.0000e+00 - loss: 0.0406
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - binary_accuracy: 0.0000e+00 - loss: 0.0398
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - binary_accuracy: 0.0000e+00 - loss: 0.0403
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - binary_accuracy: 0.0000e+00 - loss: 0.0397
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - binary_accuracy: 0.0000e+00 - loss: 0.0394
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - binary_accuracy: 0.0000e+00 - loss: 0.0396
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - binary_accuracy: 0.0000e+00 - loss: 0.0389
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - binary_accuracy: 0.0000e+00 - loss: 0.0378
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - binary_accuracy: 0.0000e+00 - loss: 0.0373
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - binary_accuracy: 0.0000e+00 - loss: 0.0366
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - binary_accuracy: 0.0000e+00 - loss: 0.0370
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - binary_accuracy: 0.0000e+00 - loss: 0.0373
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - binary_accuracy: 0.0000e+00 - loss: 0.0366
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - binary_accuracy: 0.0000e+00 - loss: 0.0354
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - binary_accuracy: 0.0000e+00 - loss: 0.0352
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - binary_accuracy: 0.0000e+00 - loss: 0.0350
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - binary_accuracy: 0.0000e+00 - loss: 0.0343
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - binary_accuracy: 0.0000e+00 - loss: 0.0323
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - binary_accuracy: 0.0000e+00 - loss: 0.0319
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - binary_accuracy: 0.0000e+00 - loss: 0.0314
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - binary_accuracy: 0.0000e+00 - loss: 0.0311
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - binary_accuracy: 0.0000e+00 - loss: 0.0315
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - binary_accuracy: 0.0000e+00 - loss: 0.0315
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - binary_accuracy: 0.0000e+00 - loss: 0.0305
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - binary_accuracy: 0.0000e+00 - loss: 0.0291
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - binary_accuracy: 0.0000e+00 - loss: 0.0283
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - binary_accuracy: 0.0000e+00 - loss: 0.0267
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - binary_accuracy: 0.0000e+00 - loss: 0.0266
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - binary_accuracy: 0.0000e+00 - loss: 0.0255
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - binary_accuracy: 0.0000e+00 - loss: 0.0252
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - binary_accuracy: 0.0000e+00 - loss: 0.0247
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - binary_accuracy: 0.0000e+00 - loss: 0.0250
# Epoch 35/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - binary_accuracy: 0.0000e+00 - loss: 0.0236
# Epoch 36/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - binary_accuracy: 0.0000e+00 - loss: 0.0224
# Epoch 37/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - binary_accuracy: 0.0000e+00 - loss: 0.0213
# Epoch 38/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - binary_accuracy: 0.0000e+00 - loss: 0.0194
# Epoch 39/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - binary_accuracy: 0.0000e+00 - loss: 0.0201
# Epoch 40/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - binary_accuracy: 0.0000e+00 - loss: 0.0187
# Epoch 41/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - binary_accuracy: 0.0000e+00 - loss: 0.0186
# Epoch 42/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - binary_accuracy: 0.0000e+00 - loss: 0.0175
# Epoch 43/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - binary_accuracy: 0.0000e+00 - loss: 0.0168
# Epoch 44/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - binary_accuracy: 0.0000e+00 - loss: 0.0153
# Epoch 45/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - binary_accuracy: 0.0000e+00 - loss: 0.0148
# Epoch 46/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - binary_accuracy: 0.0000e+00 - loss: 0.0147
# Epoch 47/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - binary_accuracy: 0.0000e+00 - loss: 0.0135
# Epoch 48/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - binary_accuracy: 0.0000e+00 - loss: 0.0124
# Epoch 49/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - binary_accuracy: 0.0000e+00 - loss: 0.0117
# Epoch 50/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - binary_accuracy: 0.0000e+00 - loss: 0.0111
# Epoch 51/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - binary_accuracy: 0.0000e+00 - loss: 0.0104
# Epoch 52/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - binary_accuracy: 0.0000e+00 - loss: 0.0103
# Epoch 53/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - binary_accuracy: 0.0000e+00 - loss: 0.0096
# Epoch 54/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.0000e+00 - loss: 0.0090
# Epoch 55/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - binary_accuracy: 0.0000e+00 - loss: 0.0083
# Epoch 56/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - binary_accuracy: 0.0000e+00 - loss: 0.0079
# Epoch 57/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - binary_accuracy: 0.0000e+00 - loss: 0.0074
# Epoch 58/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - binary_accuracy: 0.0000e+00 - loss: 0.0070
# Epoch 59/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - binary_accuracy: 0.0000e+00 - loss: 0.0063
# Epoch 60/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - binary_accuracy: 0.0000e+00 - loss: 0.0062
# Epoch 61/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - binary_accuracy: 0.0000e+00 - loss: 0.0058
# Epoch 62/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - binary_accuracy: 0.0000e+00 - loss: 0.0053
# Epoch 63/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - binary_accuracy: 0.0000e+00 - loss: 0.0049
# Epoch 64/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - binary_accuracy: 0.0000e+00 - loss: 0.0044
# Epoch 65/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - binary_accuracy: 0.0000e+00 - loss: 0.0044
# Epoch 66/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - binary_accuracy: 0.0000e+00 - loss: 0.0040
# Epoch 67/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - binary_accuracy: 0.0000e+00 - loss: 0.0038
# Epoch 68/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - binary_accuracy: 0.0000e+00 - loss: 0.0036
# Epoch 69/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - binary_accuracy: 0.0000e+00 - loss: 0.0034
# Epoch 70/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - binary_accuracy: 0.0000e+00 - loss: 0.0031
# Epoch 71/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - binary_accuracy: 0.0000e+00 - loss: 0.0028
# Epoch 72/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - binary_accuracy: 0.0000e+00 - loss: 0.0028
# Epoch 73/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - binary_accuracy: 0.0000e+00 - loss: 0.0026
# Epoch 74/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - binary_accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 75/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - binary_accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 76/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - binary_accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 77/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - binary_accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 78/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - binary_accuracy: 0.0000e+00 - loss: 0.0018
# Epoch 79/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - binary_accuracy: 0.0000e+00 - loss: 0.0017
# Epoch 80/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - binary_accuracy: 0.0000e+00 - loss: 0.0016
# Epoch 81/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - binary_accuracy: 0.0000e+00 - loss: 0.0016
# Epoch 82/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - binary_accuracy: 0.0000e+00 - loss: 0.0015
# Epoch 83/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - binary_accuracy: 0.0000e+00 - loss: 0.0014
# Epoch 84/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - binary_accuracy: 0.0000e+00 - loss: 0.0014
# Epoch 85/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - binary_accuracy: 0.0000e+00 - loss: 0.0012
# Epoch 86/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - binary_accuracy: 0.0000e+00 - loss: 0.0012
# Epoch 87/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - binary_accuracy: 0.0000e+00 - loss: 0.0012
# Epoch 88/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - binary_accuracy: 0.0000e+00 - loss: 9.8881e-04
# Epoch 89/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - binary_accuracy: 0.0000e+00 - loss: 0.0010
# Epoch 90/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - binary_accuracy: 0.0000e+00 - loss: 9.2118e-04
# Epoch 91/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - binary_accuracy: 0.0000e+00 - loss: 8.6703e-04
# Epoch 92/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - binary_accuracy: 0.0000e+00 - loss: 8.9379e-04
# Epoch 93/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - binary_accuracy: 0.0000e+00 - loss: 8.4969e-04
# Epoch 94/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - binary_accuracy: 0.0000e+00 - loss: 7.8261e-04
# Epoch 95/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - binary_accuracy: 0.0000e+00 - loss: 6.9557e-04
# Epoch 96/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - binary_accuracy: 0.0000e+00 - loss: 7.3489e-04
# Epoch 97/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - binary_accuracy: 0.0000e+00 - loss: 6.8911e-04
# Epoch 98/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - binary_accuracy: 0.0000e+00 - loss: 7.0846e-04
# Epoch 99/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - binary_accuracy: 0.0000e+00 - loss: 6.4748e-04
# Epoch 100/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - binary_accuracy: 0.0000e+00 - loss: 5.7021e-04
#
# Model evaluation:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - binary_accuracy: 0.0000e+00 - loss: 6.0728e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Some predictions:
# 0.1 + 0.2 = 0.305589884519577
# 0.2 + 0.2 = 0.4005691409111023
