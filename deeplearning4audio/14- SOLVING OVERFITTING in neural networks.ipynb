# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
# google colab

#from google.colab import drive
#drive.mount('/content/drive')

# %%
# google colab
#DATA_PATH = "/content/drive/MyDrive/Cursos/Valerio_Velardo/Deep_Learning_for_audio/data.json"

# local
DATA_PATH = "G:\My Drive\Cursos\Valerio_Velardo\Deep_Learning_for_audio\data.json"
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\M'
# <>:5: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\nehem\AppData\Local\Temp\ipykernel_18860\1474964677.py:5: SyntaxWarning: invalid escape sequence '\M'
#   DATA_PATH = "G:\My Drive\Cursos\Valerio_Velardo\Deep_Learning_for_audio\data.json"

# %%
def load_data(dataset_path):
  with open(dataset_path, 'r') as fp:
    data = json.load(fp)

  # convertir list a numpy array
  inputs = np.array(data['mfcc'])
  targets = np.array(data['labels'])
  return inputs, targets

def split_data(inputs, targets, test_size):
  return train_test_split(inputs, targets, test_size=test_size)

def plot_history(history):
  fig, axs = plt.subplots(2)

  # create accuracy subplot
  axs[0].plot(history.history['accuracy'], label='train accuracy')
  axs[0].plot(history.history['val_accuracy'], label='test accuracy')
  axs[0].set_ylabel('Accuracy')
  axs[0].legend(loc='lower right')
  axs[0].set_title('Accuracy eval')

  # create error subplot
  axs[1].plot(history.history['loss'], label='train error')
  axs[1].plot(history.history['val_loss'], label='test error')
  axs[1].set_ylabel('Error')
  axs[1].set_xlabel('Epoch')
  axs[1].legend(loc='upper right')
  axs[1].set_title('Error eval')

  plt.show()

# %%
if __name__ == "__main__":
  # load data
  inputs, targets = load_data(DATA_PATH)
  # split data into train and test set
  inputs_train, inputs_test, targets_train, targets_test = split_data(inputs, targets, 0.3)
  # build the networkt arquitecture
  model = keras.Sequential([
      # input layer
      keras.layers.Flatten(input_shape=(inputs.shape[1], inputs.shape[2])), #(time interval, value coefficient in interval)
      # 1st hidden layer
      keras.layers.Dense(512, activation='relu',kernel_regularizer=keras.regularizers.l2(0.001)),
      keras.layers.Dropout(0.3),
      # 2st hidden layer
      keras.layers.Dense(256, activation='relu',kernel_regularizer=keras.regularizers.l2(0.001)),
      keras.layers.Dropout(0.3),
      # 3st hidden layer
      keras.layers.Dense(64, activation='relu',kernel_regularizer=keras.regularizers.l2(0.001)),
      keras.layers.Dropout(0.3),
      # output layer
      keras.layers.Dense(10, activation='softmax') # 10 categories
  ])
  # compile network
  optimizer = keras.optimizers.Adam(learning_rate=0.0001)
  model.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  model.summary()

  # train network
  history = model.fit(inputs_train, targets_train, validation_data=(inputs_test, targets_test), epochs=50, batch_size=32)

  # plot accuracy and error over the epochs
  plot_history(history)
# Out:
# g:\My Drive\Cursos\Valerio_Velardo\Deep_Learning_for_audio\Code\env\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 1690)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       865,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,014,218 (3.87 MB)
#  Trainable params: 1,014,218 (3.87 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.1535 - loss: 38.6693 - val_accuracy: 0.2230 - val_loss: 3.5992
# Epoch 2/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.1645 - loss: 8.1701 - val_accuracy: 0.1796 - val_loss: 3.4309
# Epoch 3/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.1655 - loss: 5.1857 - val_accuracy: 0.1322 - val_loss: 3.4654
# Epoch 4/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.1706 - loss: 4.1757 - val_accuracy: 0.1255 - val_loss: 3.4645
# Epoch 5/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.1778 - loss: 3.8586 - val_accuracy: 0.1395 - val_loss: 3.4500
# Epoch 6/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1742 - loss: 3.6895 - val_accuracy: 0.1515 - val_loss: 3.4297
# Epoch 7/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1848 - loss: 3.5673 - val_accuracy: 0.1926 - val_loss: 3.3274
# Epoch 8/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2076 - loss: 3.5022 - val_accuracy: 0.2183 - val_loss: 3.2690
# Epoch 9/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2198 - loss: 3.4585 - val_accuracy: 0.2016 - val_loss: 3.2966
# Epoch 10/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2179 - loss: 3.4318 - val_accuracy: 0.2136 - val_loss: 3.2673
# Epoch 11/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2359 - loss: 3.3352 - val_accuracy: 0.2440 - val_loss: 3.2067
# Epoch 12/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2453 - loss: 3.3014 - val_accuracy: 0.2370 - val_loss: 3.1830
# Epoch 13/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2504 - loss: 3.2609 - val_accuracy: 0.2463 - val_loss: 3.1438
# Epoch 14/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2558 - loss: 3.2464 - val_accuracy: 0.3124 - val_loss: 3.1094
# Epoch 15/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2630 - loss: 3.2149 - val_accuracy: 0.2840 - val_loss: 3.1154
# Epoch 16/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2609 - loss: 3.1919 - val_accuracy: 0.3151 - val_loss: 3.0133
# Epoch 17/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2767 - loss: 3.1113 - val_accuracy: 0.2984 - val_loss: 3.0406
# Epoch 18/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2751 - loss: 3.1262 - val_accuracy: 0.2997 - val_loss: 3.0440
# Epoch 19/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2872 - loss: 3.0679 - val_accuracy: 0.3521 - val_loss: 2.9298
# Epoch 20/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3040 - loss: 3.0496 - val_accuracy: 0.3438 - val_loss: 2.9562
# Epoch 21/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3183 - loss: 2.9864 - val_accuracy: 0.3598 - val_loss: 2.9143
# Epoch 22/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3029 - loss: 2.9875 - val_accuracy: 0.3808 - val_loss: 2.8379
# Epoch 23/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3124 - loss: 2.9568 - val_accuracy: 0.3989 - val_loss: 2.8307
# Epoch 24/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3208 - loss: 2.9192 - val_accuracy: 0.3992 - val_loss: 2.8097
# Epoch 25/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3306 - loss: 2.8681 - val_accuracy: 0.3942 - val_loss: 2.7884
# Epoch 26/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3326 - loss: 2.8477 - val_accuracy: 0.3802 - val_loss: 2.7514
# Epoch 27/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3392 - loss: 2.8136 - val_accuracy: 0.3692 - val_loss: 2.7246
# Epoch 28/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3471 - loss: 2.8111 - val_accuracy: 0.3909 - val_loss: 2.7097
# Epoch 29/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3344 - loss: 2.7838 - val_accuracy: 0.3892 - val_loss: 2.6828
# Epoch 30/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3551 - loss: 2.7379 - val_accuracy: 0.4079 - val_loss: 2.6608
# Epoch 31/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3498 - loss: 2.7215 - val_accuracy: 0.3989 - val_loss: 2.6373
# Epoch 32/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3610 - loss: 2.6706 - val_accuracy: 0.3935 - val_loss: 2.6361
# Epoch 33/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3613 - loss: 2.6426 - val_accuracy: 0.4222 - val_loss: 2.5667
# Epoch 34/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3754 - loss: 2.5859 - val_accuracy: 0.4202 - val_loss: 2.5907
# Epoch 35/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3780 - loss: 2.5786 - val_accuracy: 0.4309 - val_loss: 2.5027
# Epoch 36/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3711 - loss: 2.5610 - val_accuracy: 0.4192 - val_loss: 2.4927
# Epoch 37/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3880 - loss: 2.5195 - val_accuracy: 0.4339 - val_loss: 2.4269
# Epoch 38/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4065 - loss: 2.4371 - val_accuracy: 0.4349 - val_loss: 2.4364
# Epoch 39/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3983 - loss: 2.4440 - val_accuracy: 0.4383 - val_loss: 2.3996
# Epoch 40/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4123 - loss: 2.3931 - val_accuracy: 0.4456 - val_loss: 2.3917
# Epoch 41/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4005 - loss: 2.3713 - val_accuracy: 0.4619 - val_loss: 2.3830
# Epoch 42/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.4167 - loss: 2.3593 - val_accuracy: 0.4516 - val_loss: 2.3269
# Epoch 43/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4274 - loss: 2.2783 - val_accuracy: 0.4609 - val_loss: 2.3223
# Epoch 44/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4322 - loss: 2.2591 - val_accuracy: 0.4626 - val_loss: 2.3230
# Epoch 45/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4459 - loss: 2.2046 - val_accuracy: 0.4619 - val_loss: 2.2887
# Epoch 46/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4450 - loss: 2.1989 - val_accuracy: 0.4723 - val_loss: 2.2444
# Epoch 47/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4537 - loss: 2.1844 - val_accuracy: 0.4723 - val_loss: 2.2561
# Epoch 48/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4538 - loss: 2.1496 - val_accuracy: 0.4676 - val_loss: 2.1922
# Epoch 49/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4488 - loss: 2.1388 - val_accuracy: 0.4836 - val_loss: 2.2118
# Epoch 50/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4805 - loss: 2.0604 - val_accuracy: 0.4603 - val_loss: 2.1784
